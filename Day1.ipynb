# %% [markdown]
# # Data Type

# %%
# comments - single line comments

# %%
'''this
is
the
muti
line
comments
'''
# Out:
# 'this\nis\nthe\nmuti\nline\ncomments\n'

# %%
# Data Type

# %%
# Int - Integer

# %%
a = 20

# %%
pmmodi = 20

# %%
print(a)
# Out:
# 20

# %%
a = -50

# %%
type(a)      # type () built in function
# Out:
# int

# %%
# float

# %%
a = 5.6

# %%
type(a)
# Out:
# float

# %%
# ( ) - paranthesis - function
# [ ] - square braces
# { } - curly braces

# %%
# complex

# %%
a = 3 + 4j

# %%
type(a)
# Out:
# complex

# %%
# string

# %%
a = "gayatri"

# %%
type(a)
# Out:
# str

# %%
a = gayatri
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4130433338.py in <cell line: 0>()
# ----> 1 a = gayatri
#
# NameError: name 'gayatri' is not defined

# %%
gayatri
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2402566847.py in <cell line: 0>()
# ----> 1 gayatri
#
# NameError: name 'gayatri' is not defined

# %%
gayatri = 10

# %%
gayatri
# Out:
# 10

# %%
a = gayatri

# %%
a
# Out:
# 10

# %%
# sequence data type

# %%
a = 10

# %%
# LIST - [ ] - Always in square braces

# %%
a = [10,20,30,40,50]

# %%
type(a)
# Out:
# list

# %%
a
# Out:
# [10, 20, 30, 40, 50]

# %%
# SET - { } - Always in curly beaces

# %%
a= {10,20,30,40,50}

# %%
type(a)
# Out:
# set

# %%
a
# Out:
# {10, 20, 30, 40, 50}

# %%
# TUPLE - ( ) - Always in paranthesis

# %%
a = (10,20,30,40,50,60)

# %%
type(a)
# Out:
# tuple

# %%
# DICTIONERY - Dict - {Key : value}

# %%
student1 = {"name":"pratiksha",
             "age":18,
             "city":"wardha"}

# %%
type(student1)
# Out:
# dict

# %%
a = {1:"pratiksha", 2:"pradip"}

# %%
type(a)
# Out:
# dict

# %%
# Operators

# %%
# arithematic operator

# %%
# addition

# %%
10 + 20
# Out:
# 30

# %%
a = 10
b = 20
a + b
# Out:
# 30

# %%
# python is a case sensetive

# %%
a = 20

# %%
# tushar / Tushar / TuShAr / TUSHAR / TushaR

# %%
a = 10
b = 20
c = a + b

# %%
c
# Out:
# 30

# %%
print(c)
# Out:
# 30

# %%
# Substraction

# %%
50 - 20
# Out:
# 30

# %%
a = 50
b = 20

# %%
c
# Out:
# 30

# %%
# multiplication

# %%
20 * 30
# Out:
# 600

# %%
a * b
# Out:
# 1000

# %%
# division

# %%
50 / 5
# Out:
# 10.0

# %%
25 / 3
# Out:
# 8.333333333333334

# %%
a / b
# Out:
# 2.5

# %%
# floor division

# %%
20 / 3
# Out:
# 6.666666666666667

# %%
20 // 3
# Out:
# 6

# %%
# modulus % - use for reminder

# %%
20 % 3
# Out:
# 2

# %%
9 % 2
# Out:
# 1

# %%
# exponantiation - ** - power

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %%
5 ** 2
# Out:
# 25

# %%
5 ** 3
# Out:
# 125
