# %% [markdown]
# # Data Loading and preprocessing
#
# # Handling Missing Values and Data Cleaning
#
# # Descriptive Statistics and Summay
#
# # Visualization (Univariate, bivariate, multivariate)
#
# # Insights on Churn Behaviour

# %%
# load important librabires for EDA project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data into df variable

# %%
df = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# as we see the data is huge. So all columns not showing
# So lets check the total columns name

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# lets check the shape of data

# %%
df.shape
# Out:
# (7043, 21)

# %%
# The data set contains 7043 rows indicate customers with 21 features
# Each row represent a unique customer with various attributes
# related to demographic, services and billing
# The dataset size is sufficient for meaningful analysis and prediction
# with 21 features, we have a good mix of xategorical and numerical
# to explore customer behaviour and churn pattern.

# %%
# lets check data types of each feature

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# most of the columns are categorical (object type)
# SeniorCitizen is stored as int64, but since its a binary variable
# 0 & 1 it can be treated as categorical
# Total charges is stored as an object, which seems incorrect
# Since it represent a numerical values
# It may contain missing values or be formatted incorrect
# We need to convert it to float for proper analysis

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# check the conversion

# %%
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
# Check for missing values in each columns

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# only one column TotalCharges has missing values
# 11 missing values
# Since Total Charges is numerical, these missing values were
# likely empty spaces in original dataset before conversion
# possible ways to handle missing values:-
# 1 - fill them with median or mean of TotalCharges
# 2 - fill them with zero, but total charges not be zero
# 3 - Drop these 11 rows, but if we do 11 customers also drop for 7043. We myloss data
# So better to fill the missing value
# fill them with median, beacuse median is good if we may contain outlier

# %%
df['TotalCharges'].median()
# Out:
# 1397.475

# %%
df['TotalCharges'].mean()
# Out:
# np.float64(2283.3004408418656)

# %%
df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)
# Out:
# /tmp/ipython-input-2840544469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

# %%
# so lets check the missing value again

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Lets check for the duplicate records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
categorical_columns= ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']

# %%
for i in categorical_columns:
  print(f"Unique value in {i} is :- ")
  print(df[i].unique(), "\n")
  print("---------------------------")
# Out:
# Unique value in gender is :-
# ['Female' 'Male']
#
# ---------------------------
# Unique value in SeniorCitizen is :-
# [0 1]
#
# ---------------------------
# Unique value in Partner is :-
# ['Yes' 'No']
#
# ---------------------------
# Unique value in Dependents is :-
# ['No' 'Yes']
#
# ---------------------------
# Unique value in PhoneService is :-
# ['No' 'Yes']
#
# ---------------------------
# Unique value in MultipleLines is :-
# ['No phone service' 'No' 'Yes']
#
# ---------------------------
# Unique value in InternetService is :-
# ['DSL' 'Fiber optic' 'No']
#
# ---------------------------
# Unique value in OnlineSecurity is :-
# ['No' 'Yes' 'No internet service']
#
# ---------------------------
# Unique value in OnlineBackup is :-
# ['Yes' 'No' 'No internet service']
#
# ---------------------------
# Unique value in DeviceProtection is :-
# ['No' 'Yes' 'No internet service']
#
# ---------------------------
# Unique value in TechSupport is :-
# ...

# %%
# lets check for the distribution of numerical feature
# also check the outliers

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data = df, x= 'MonthlyCharges')
plt.title("Monthly Charges Boxplot")
# Out:
# Text(0.5, 1.0, 'Monthly Charges Boxplot')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data = df, x= 'TotalCharges')
plt.title("Total Charges Boxplot")
# Out:
# Text(0.5, 1.0, 'Total Charges Boxplot')

# %%
# Since there are no outlier in the Monthly Charges and Total Charges
# This is the clean data distribution
# No extreme values are distorting the distribution
# This mean data is already well behaved for statistical analysis and modeling
# No need for transformation or removal

# %%
df[["TotalCharges", "MonthlyCharges", "tenure"]].describe()
# Out:
#        TotalCharges  MonthlyCharges       tenure
# count   7043.000000     7043.000000  7043.000000
# mean    2281.916928       64.761692    32.371149
# std     2265.270398       30.090047    24.559481
# min       18.800000       18.250000     0.000000
# 25%      402.225000       35.500000     9.000000
# 50%     1397.475000       70.350000    29.000000
# 75%     3786.600000       89.850000    55.000000
# max     8684.800000      118.750000    72.000000

# %%
# The average of TotalCharge per customer is 2281.91
# and the median that is middle value is 1397.48, which is significantly
# indicate that median is lower than mean i.e., right skew distribution
# The MonthlyCharge also little bit left skew
# The median tenure is 29 month. maximum customer is for long term

# %%
# To understand the distribution of the tenure among customer

# %%
# Histogram / kde plot

# %%
plt.figure(figsize= (10,6))
sns.histplot(data=df, x='tenure', kde=True, bins=40)
plt.title("Distribution of tenure among customer")
# Out:
# Text(0.5, 1.0, 'Distribution of tenure among customer')

# %%
# the fact that the distribution looks uniform, suggest that customers are
# evenly distribution accross different tenure range
# so lets check for the MonthlyCharges and TotalCharges distribution

# %%
plt.figure(figsize= (12,6))

plt.subplot(1,2,1)
sns.histplot(data=df, x="MonthlyCharges", kde=True, bins=40)
plt.title("Distribution of Monthly Charges")

plt.subplot(1,2,2)
sns.histplot(data=df, x="TotalCharges", kde=True, bins=40)
plt.title("Distribution of total Charges")

plt.tight_layout()

# %%
# MontlyCharges- symmetric distribution spread accross 18 to 118
# TotalCharges- right skewed with many low charges customers

# %%
# lets check for the categorical columns

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Contract', hue='Churn', palette='viridis')
plt.title("Customers count by Contract")
# Out:
# Text(0.5, 1.0, 'Customers count by Contract')

# %%
df.groupby("Contract")["Churn"].value_counts().unstack()
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
df.groupby("Contract")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
# Majority of customers approx 42% are on month-to-month which is potential churn
# One year and two year contract indicating higher stability
# business impication - customers on month-to-month contracts
# may need loyalty discount to commit a longer contract
# long-term customers should be rewarded with better benefit to maintain
# retention

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Lets check for the serniorCitizen

# %%
df['SeniorCitizen'].value_counts()
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
df['SeniorCitizen'].value_counts(normalize=True)*100
# Out:
# SeniorCitizen
# 0    83.785319
# 1    16.214681
# Name: proportion, dtype: float64

# %%
# Around 16% of the customers are SeniorCitizens.

# so lets check for the churn rate

# %%
df.groupby("SeniorCitizen")["Churn"].value_counts().unstack()
# Out:
# Churn            No   Yes
# SeniorCitizen
# 0              4508  1393
# 1               666   476

# %%
df.groupby("SeniorCitizen")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 0              76.393832  23.606168
# 1              58.318739  41.681261

# %%
# Insights may check the Senior Citizens Income source..
# If we impliment the discount for the senior citizen then the churn rate
# may minimize..
# May be they dont get the better customer supports. ex. phone assistance
# Implimentation AND simplified billing and payment options

# %%
sns.countplot(data=df, x='SeniorCitizen', hue='Churn', palette="Set1")
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %%
Seniordf = df[df['SeniorCitizen']==1]

# %%
SC = Seniordf.groupby("SeniorCitizen")["Churn"].value_counts(normalize=True).unstack()*100

# %%
SC
# Out:
# Churn                 No        Yes
# SeniorCitizen
# 1              58.318739  41.681261

# %%
plt.figure(figsize= (5,5))
plt.pie(SC.loc[1].values, labels=SC.loc[1].index, autopct="%1.2f%%")
plt.title("Proportion of Senior Citizen")
# Out:
# Text(0.5, 1.0, 'Proportion of Senior Citizen')

# %%
# Lets check for partners

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df['Partner'].value_counts(normalize=True)*100
# Out:
# Partner
# No     51.69672
# Yes    48.30328
# Name: proportion, dtype: float64

# %%
df.groupby("Partner")["Churn"].value_counts().unstack()
# Out:
# Churn      No   Yes
# Partner
# No       2441  1200
# Yes      2733   669

# %%
df.groupby("Partner")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn           No        Yes
# Partner
# No       67.042021  32.957979
# Yes      80.335097  19.664903

# %%
sns.countplot(data=df, x='Partner', hue='Churn', palette="Set1")
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %%
Partnerdf = df[df['Partner']=='No']

# %%
No_Partner = Partnerdf.groupby("Partner")["Churn"].value_counts(normalize=True).unstack()*100

# %%
No_Partner
# Out:
# Churn           No        Yes
# Partner
# No       67.042021  32.957979

# %%
plt.figure(figsize= (5,5))
plt.pie(No_Partner.loc['No'].values, labels=No_Partner.loc['No'].index, autopct="%1.2f%%")
plt.title("Proportion of No Partner")
# Out:
# Text(0.5, 1.0, 'Proportion of No Partner')

# %%
Partnerdf = df[df['Partner']=='Yes']

# %%
Partner = Partnerdf.groupby("Partner")["Churn"].value_counts(normalize=True).unstack()*100

# %%
Partner
# Out:
# Churn           No        Yes
# Partner
# Yes      80.335097  19.664903

# %%
plt.figure(figsize=(5,5))
plt.pie(Partner.loc['Yes'].values, labels=Partner.loc['Yes'].index, autopct="%1.2f%%")
plt.title("Proportion of Partner")
# Out:
# Text(0.5, 1.0, 'Proportion of Partner')

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.pie(Partner.loc['Yes'].values, labels=Partner.loc['Yes'].index, autopct="%1.2f%%")
plt.title("Proportion of Partner")


plt.subplot(1,2,2)
plt.pie(No_Partner.loc['No'].values, labels=No_Partner.loc['No'].index, autopct="%1.2f%%")
plt.title("Proportion of No Partner")
# Out:
# Text(0.5, 1.0, 'Proportion of No Partner')

# %%
# Lets check for InternetService

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df['InternetService'].value_counts(normalize=True)*100
# Out:
# InternetService
# Fiber optic    43.958540
# DSL            34.374556
# No             21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("InternetService")["Churn"].value_counts().unstack()
# Out:
# Churn              No   Yes
# InternetService
# DSL              1962   459
# Fiber optic      1799  1297
# No               1413   113

# %%
df.groupby("InternetService")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %%
sns.countplot(data=df, x='InternetService', hue='Churn', palette="rocket")
plt.title("Internet Service Customers")
# Out:
# Text(0.5, 1.0, 'Internet Service Customers')

# %%
IS = df.groupby("InternetService")["Churn"].value_counts(normalize=True).unstack()*100

# %%
IS
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %%
labels = IS.index.tolist()
not_churn = IS["No"].tolist()
churn = IS["Yes"].tolist()

# %%
labels
# Out:
# ['DSL', 'Fiber optic', 'No']

# %%
not_churn
# Out:
# [81.04089219330855, 58.10723514211886, 92.59501965923984]

# %%
churn
# Out:
# [18.95910780669145, 41.89276485788114, 7.404980340760157]

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pie(churn, labels=labels, autopct="%1.2f%%")
plt.title("Churn percentage by Internet Service")

plt.subplot(1,2,2)
plt.pie(not_churn, labels=labels, autopct="%1.2f%%")
plt.title("Not Churn percentage by Internet Service")
# Out:
# Text(0.5, 1.0, 'Not Churn percentage by Internet Service')

# %%
withDSL = df[df['InternetService']=='DSL']

# %%
DSL = withDSL.groupby("InternetService")["Churn"].value_counts(normalize=True).unstack()*100

# %%
DSL
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108

# %%
plt.pie(DSL.loc["DSL"].values, labels=DSL.loc["DSL"].index, autopct="%1.2f%%")
plt.title("DSL Internet Service")
# Out:
# Text(0.5, 1.0, 'DSL Internet Service')

# %%
withFiberoptic = df[df['InternetService']=='Fiber optic']

# %%
Fiber_optic = withFiberoptic.groupby("InternetService")["Churn"].value_counts(normalize=True).unstack()*100

# %%
Fiber_optic
# Out:
# Churn                   No        Yes
# InternetService
# Fiber optic      58.107235  41.892765

# %%
plt.pie(Fiber_optic.loc["Fiber optic"].values, labels=Fiber_optic.loc["Fiber optic"].index, autopct="%1.2f%%")
plt.title("Fiber Optic Internet Service")
# Out:
# Text(0.5, 1.0, 'Fiber Optic Internet Service')

# %%
withNo = df[df['InternetService']=='No']

# %%
No = withNo.groupby("InternetService")["Churn"].value_counts(normalize=True).unstack()*100

# %%
No
# Out:
# Churn                  No      Yes
# InternetService
# No               92.59502  7.40498

# %%
plt.pie(No.loc["No"].values, labels=No.loc["No"].index, autopct="%1.2f%%")
plt.title("No Internet Service")
# Out:
# Text(0.5, 1.0, 'No Internet Service')

# %%
# Lets check for Gender

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df['gender'].value_counts(normalize=True)*100
# Out:
# gender
# Male      50.47565
# Female    49.52435
# Name: proportion, dtype: float64

# %%
df.groupby("gender")["Churn"].value_counts().unstack()
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %%
df.groupby("gender")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn          No        Yes
# gender
# Female  73.079128  26.920872
# Male    73.839662  26.160338

# %%
sns.countplot(data=df, x='gender', hue='Churn', palette="rocket")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
newdf=df[df['gender']=='Female']

# %%
Female =newdf.groupby("gender")["Churn"].value_counts(normalize=True).unstack()*100

# %%
Female
# Out:
# Churn          No        Yes
# gender
# Female  73.079128  26.920872

# %%
plt.pie(Female.loc["Female"].values, labels=Female.loc["Female"].index, autopct="%1.2f%%")
plt.title("Female")
# Out:
# Text(0.5, 1.0, 'Female')

# %%
newdf2 = df[df['gender']=='Male']

# %%
Male = newdf2.groupby("gender")["Churn"].value_counts(normalize=True).unstack()*100

# %%
Male
# Out:
# Churn          No        Yes
# gender
# Male    73.839662  26.160338

# %%
plt.pie(Male.loc["Male"].values, labels=Male.loc["Male"].index, autopct="%1.2f%%")
plt.title("Male")
# Out:
# Text(0.5, 1.0, 'Male')

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.pie(Female.loc['Female'].values, labels=Female.loc['Female'].index, autopct="%1.2f%%")
plt.title("Female")


plt.subplot(1,2,2)
plt.pie(Male.loc['Male'].values, labels=Male.loc['Male'].index, autopct="%1.2f%%")
plt.title("Male")
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Lets check for Dependents

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df['Dependents'].value_counts(normalize=True)*100
# Out:
# Dependents
# No     70.041176
# Yes    29.958824
# Name: proportion, dtype: float64

# %%
df.groupby("Dependents")["Churn"].value_counts().unstack()
# Out:
# Churn         No   Yes
# Dependents
# No          3390  1543
# Yes         1784   326

# %%
df.groupby("Dependents")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn              No        Yes
# Dependents
# No          68.720860  31.279140
# Yes         84.549763  15.450237

# %%
sns.countplot(data=df, x="Dependents", hue="Churn", palette="rocket")
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
dependents = df[df["Dependents"]=="No"]

# %%
notdependents = dependents.groupby("Dependents")["Churn"].value_counts(normalize=True).unstack()*100

# %%
notdependents
# Out:
# Churn             No       Yes
# Dependents
# No          68.72086  31.27914

# %%
plt.pie(notdependents.loc["No"].values, labels=notdependents.loc["No"].index, autopct="%1.2f%%")
plt.title("Not Dependents")
# Out:
# Text(0.5, 1.0, 'Not Dependents')

# %%
dependents1 = df[df["Dependents"]=="Yes"]

# %%
Dependents = dependents1.groupby("Dependents")["Churn"].value_counts(normalize=True).unstack()*100

# %%
Dependents
# Out:
# Churn              No        Yes
# Dependents
# Yes         84.549763  15.450237

# %%
plt.pie(Dependents.loc["Yes"].values, labels=Dependents.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Dependents")
# Out:
# Text(0.5, 1.0, 'Dependents')

# %%
# Lets check for PhoneService

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df['PhoneService'].value_counts(normalize=True)*100
# Out:
# PhoneService
# Yes    90.316626
# No      9.683374
# Name: proportion, dtype: float64

# %%
df.groupby('PhoneService')['Churn'].value_counts().unstack()
# Out:
# Churn           No   Yes
# PhoneService
# No             512   170
# Yes           4662  1699

# %%
df.groupby('PhoneService')['Churn'].value_counts(normalize=True).unstack()*100
# Out:
# Churn                No        Yes
# PhoneService
# No            75.073314  24.926686
# Yes           73.290363  26.709637

# %%
sns.countplot(data=df, x="PhoneService", hue="Churn", palette="viridis")
# Out:
# <Axes: xlabel='PhoneService', ylabel='count'>

# %%
PhoneService1 = df[df['PhoneService']=='No']

# %%
PS1 = PhoneService1.groupby('PhoneService')['Churn'].value_counts(normalize=True).unstack()*100

# %%
PS1
# Out:
# Churn                No        Yes
# PhoneService
# No            75.073314  24.926686

# %%
plt.pie(PS1.loc["No"].values, labels=PS1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Phone Service")
# Out:
# Text(0.5, 1.0, 'No Phone Service')

# %%
PhoneService2 = df[df["PhoneService"]=="Yes"]

# %%
PS2 = PhoneService2.groupby('PhoneService')['Churn'].value_counts(normalize=True).unstack()*100

# %%
PS2
# Out:
# Churn                No        Yes
# PhoneService
# Yes           73.290363  26.709637

# %%
plt.pie(PS2.loc["Yes"].values, labels=PS2.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Phone Service")
# Out:
# Text(0.5, 1.0, 'Phone Service')

# %%
# Lets check for Multiple Lines

# %%
df["MultipleLines"].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df["MultipleLines"].value_counts(normalize=True)*100
# Out:
# MultipleLines
# No                  48.132898
# Yes                 42.183729
# No phone service     9.683374
# Name: proportion, dtype: float64

# %%
df.groupby("MultipleLines")["Churn"].value_counts().unstack()
# Out:
# Churn               No  Yes
# MultipleLines
# No                2541  849
# No phone service   512  170
# Yes               2121  850

# %%
df.groupby("MultipleLines")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn                    No        Yes
# MultipleLines
# No                74.955752  25.044248
# No phone service  75.073314  24.926686
# Yes               71.390104  28.609896

# %%
sns.countplot(data=df, x="MultipleLines", hue="Churn", palette="rocket")
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
Multiplelines = df[df['MultipleLines']=="No"]

# %%
MPL1 = Multiplelines.groupby('MultipleLines')['Churn'].value_counts(normalize=True).unstack()*100

# %%
MPL1
# Out:
# Churn                 No        Yes
# MultipleLines
# No             74.955752  25.044248

# %%
plt.pie(MPL1.loc["No"].values, labels=MPL1.loc["No"].index, autopct="%1.2f%%")
plt.title("Multiple Lines")
# Out:
# Text(0.5, 1.0, 'Multiple Lines')

# %%
Multiplelines = df[df['MultipleLines']=="No phone service"]

# %%
MPL2 = Multiplelines.groupby('MultipleLines')['Churn'].value_counts(normalize=True).unstack()*100

# %%
MPL2
# Out:
# Churn                    No        Yes
# MultipleLines
# No phone service  75.073314  24.926686

# %%
plt.pie(MPL2.loc["No phone service"].values, labels=MPL2.loc["No phone service"].index, autopct="%1.2f%%")
plt.title("Multiple Lines")
# Out:
# Text(0.5, 1.0, 'Multiple Lines')

# %%
Multiplelines = df[df['MultipleLines']=="Yes"]

# %%
MPL3 = Multiplelines.groupby('MultipleLines')['Churn'].value_counts(normalize=True).unstack()*100

# %%
MPL3
# Out:
# Churn                 No        Yes
# MultipleLines
# Yes            71.390104  28.609896

# %%
plt.pie(MPL3.loc["Yes"].values, labels=MPL3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Multiple Lines")
# Out:
# Text(0.5, 1.0, 'Multiple Lines')

# %%
# Lets check for OnlineSecurity

# %%
df["OnlineSecurity"].value_counts()
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
df["OnlineSecurity"].value_counts(normalize=True)*100
# Out:
# OnlineSecurity
# No                     49.666335
# Yes                    28.666761
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby("OnlineSecurity")["Churn"].value_counts().unstack()
# Out:
# Churn                  No   Yes
# OnlineSecurity
# No                   2037  1461
# No internet service  1413   113
# Yes                  1724   295

# %%
df.groupby("OnlineSecurity")["Churn"].value_counts(normalize=True).unstack()*100
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.233276  41.766724
# No internet service  92.595020   7.404980
# Yes                  85.388806  14.611194

# %%
sns.countplot(data=df, x="OnlineSecurity", hue="Churn", palette="rocket")
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %%
Onlinesecurity = df[df["OnlineSecurity"]=="No"]

# %%
OS1 = Onlinesecurity.groupby("OnlineSecurity")["Churn"].value_counts(normalize=True).unstack()*100

# %%
OS1
# Out:
# Churn                  No        Yes
# OnlineSecurity
# No              58.233276  41.766724

# %%
plt.pie(OS1.loc["No"], labels=OS1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Online Security")
# Out:
# Text(0.5, 1.0, 'No Online Security')

# %%
Onlinesecurity = df[df['OnlineSecurity']=="No internet service"]

# %%
OS2 = Onlinesecurity.groupby('OnlineSecurity')['Churn'].value_counts(normalize=True).unstack()*100

# %%
OS2
# Out:
# Churn                      No      Yes
# OnlineSecurity
# No internet service  92.59502  7.40498

# %%
plt.pie(OS2.loc["No internet service"], labels=OS2.loc["No internet service"].index, autopct="%1.2f%%")
plt.title("No internet service ")
# Out:
# Text(0.5, 1.0, 'No internet service ')

# %%
Onlinesecurity = df[df['OnlineSecurity']=="Yes"]

# %%
OS3 = Onlinesecurity.groupby('OnlineSecurity')['Churn'].value_counts(normalize=True).unstack()*100

# %%
OS3
# Out:
# Churn                  No        Yes
# OnlineSecurity
# Yes             85.388806  14.611194

# %%
plt.pie(OS3.loc["Yes"], labels=OS3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Online Security")
# Out:
# Text(0.5, 1.0, 'Online Security')

# %%
# Lets check for OnlineBackup

# %%
df['OnlineBackup'].value_counts()
# Out:
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64

# %%
df['OnlineBackup'].value_counts(normalize=True)*100
# Out:
# OnlineBackup
# No                     43.844952
# Yes                    34.488144
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby('OnlineBackup')['Churn'].value_counts().unstack()
# Out:
# Churn                  No   Yes
# OnlineBackup
# No                   1855  1233
# No internet service  1413   113
# Yes                  1906   523

# %%
df.groupby('OnlineBackup')['Churn'].value_counts(normalize=True).unstack()*100
# Out:
# Churn                       No        Yes
# OnlineBackup
# No                   60.071244  39.928756
# No internet service  92.595020   7.404980
# Yes                  78.468506  21.531494

# %%
sns.countplot(data=df, x="OnlineBackup", hue="Churn", palette="Set2")
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %%
Onlinebackup = df[df['OnlineBackup']=="No"]

# %%
OB1 = Onlinebackup.groupby('OnlineBackup')['Churn'].value_counts(normalize=True).unstack()*100

# %%
OB1
# Out:
# Churn                No        Yes
# OnlineBackup
# No            60.071244  39.928756

# %%
plt.pie(OB1.loc["No"], labels=OB1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Online Backup")
# Out:
# Text(0.5, 1.0, 'No Online Backup')

# %%
Onlinebackup = df[df['OnlineBackup']=="No internet service"]

# %%
OB2 = Onlinebackup.groupby('OnlineBackup')['Churn'].value_counts(normalize=True).unstack()*100

# %%
OB2
# Out:
# Churn                      No      Yes
# OnlineBackup
# No internet service  92.59502  7.40498

# %%
plt.pie(OB2.loc["No internet service"], labels=OB2.loc["No internet service"].index, autopct="%1.2f%%")
plt.title("No internet service")
# Out:
# Text(0.5, 1.0, 'No internet service')

# %%
Onlinebackup = df[df['OnlineBackup']=="Yes"]

# %%
OB3 = Onlinebackup.groupby('OnlineBackup')['Churn'].value_counts(normalize=True).unstack()*100

# %%
OB3
# Out:
# Churn                No        Yes
# OnlineBackup
# Yes           78.468506  21.531494

# %%
plt.pie(OB3.loc["Yes"], labels=OB3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Online Backup")
# Out:
# Text(0.5, 1.0, 'Online Backup')

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Lets check for DeviceProtection

# %%
df['DeviceProtection'].value_counts()
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
df['DeviceProtection'].value_counts(normalize=True)*100
# Out:
# DeviceProtection
# No                     43.944342
# Yes                    34.388755
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby('DeviceProtection')['Churn'].value_counts().unstack()
# Out:
# Churn                  No   Yes
# DeviceProtection
# No                   1884  1211
# No internet service  1413   113
# Yes                  1877   545

# %%
df.groupby('DeviceProtection')['Churn'].value_counts(normalize=True).unstack()*100
# Out:
# Churn                       No        Yes
# DeviceProtection
# No                   60.872375  39.127625
# No internet service  92.595020   7.404980
# Yes                  77.497936  22.502064

# %%
sns.countplot(data=df, x="DeviceProtection", hue="Churn", palette="viridis")
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %%
DeviceProtection = df[df['DeviceProtection']=="No"]

# %%
DP1 = DeviceProtection.groupby('DeviceProtection')['Churn'].value_counts(normalize=True).unstack()*100

# %%
DP1
# Out:
# Churn                    No        Yes
# DeviceProtection
# No                60.872375  39.127625

# %%
plt.pie(DP1.loc["No"], labels=DP1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Device Protection")
# Out:
# Text(0.5, 1.0, 'No Device Protection')

# %%
DeviceProtection = df[df['DeviceProtection']=="No internet service"]

# %%
DP2 = DeviceProtection.groupby('DeviceProtection')['Churn'].value_counts(normalize=True).unstack()*100

# %%
DP2
# Out:
# Churn                      No      Yes
# DeviceProtection
# No internet service  92.59502  7.40498

# %%
plt.pie(DP2.loc["No internet service"], labels=DP2.loc["No internet service"].index, autopct="%1.2f%%")
plt.title("No Internet Service")
# Out:
# Text(0.5, 1.0, 'No Internet Service')

# %%
DeviceProtection = df[df['DeviceProtection']=="Yes"]

# %%
DP3 = DeviceProtection.groupby('DeviceProtection')['Churn'].value_counts(normalize=True).unstack()*100

# %%
DP3
# Out:
# Churn                    No        Yes
# DeviceProtection
# Yes               77.497936  22.502064

# %%
plt.pie(DP3.loc["Yes"], labels=DP3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Device Protection")
# Out:
# Text(0.5, 1.0, 'Device Protection')

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
df['TechSupport'].value_counts(normalize=True)*100
# Out:
# TechSupport
# No                     49.311373
# Yes                    29.021724
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby('TechSupport')['Churn'].value_counts().unstack()
# Out:
# Churn                  No   Yes
# TechSupport
# No                   2027  1446
# No internet service  1413   113
# Yes                  1734   310

# %%
df.groupby('TechSupport')['Churn'].value_counts(normalize=True).unstack()*100
# Out:
# Churn                       No        Yes
# TechSupport
# No                   58.364526  41.635474
# No internet service  92.595020   7.404980
# Yes                  84.833659  15.166341

# %%
sns.countplot(data=df, x="TechSupport", hue="Churn", palette="Set2")
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %%
TechSupport = df[df['TechSupport']=='No']

# %%
TS1 = TechSupport.groupby('TechSupport')['Churn'].value_counts(normalize=True).unstack()*100

# %%
TS1
# Out:
# Churn               No        Yes
# TechSupport
# No           58.364526  41.635474

# %%
plt.pie(TS1.loc["No"], labels=TS1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Tech Support")
# Out:
# Text(0.5, 1.0, 'No Tech Support')

# %%
TechSupport = df[df['TechSupport']=="No internet service"]

# %%
TS2 = TechSupport.groupby('TechSupport')['Churn'].value_counts(normalize=True).unstack()*100

# %%
TS2
# Out:
# Churn                      No      Yes
# TechSupport
# No internet service  92.59502  7.40498

# %%
plt.pie(TS2.loc["No internet service"], labels=TS2.loc["No internet service"].index, autopct="%1.2f%%")
plt.title("No Internet Service")
# Out:
# Text(0.5, 1.0, 'No Internet Service')

# %%
TechSupport = df[df['TechSupport']=="Yes"]

# %%
TS3 = TechSupport.groupby('TechSupport')['Churn'].value_counts(normalize=True).unstack()*100

# %%
TS3
# Out:
# Churn               No        Yes
# TechSupport
# Yes          84.833659  15.166341

# %%
plt.pie(TS3.loc["Yes"], labels=TS3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Tech Support")
# Out:
# Text(0.5, 1.0, 'Tech Support')

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Lets check for StreamingTV

# %%
df['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
df['StreamingTV'].value_counts(normalize=True)*100
# Out:
# StreamingTV
# No                     39.897771
# Yes                    38.435326
# No internet service    21.666903
# Name: proportion, dtype: float64

# %%
df.groupby('StreamingTV')['Churn'].value_counts().unstack()
# Out:
# Churn                  No  Yes
# StreamingTV
# No                   1868  942
# No internet service  1413  113
# Yes                  1893  814

# %%
df.groupby('StreamingTV')['Churn'].value_counts(normalize=True).unstack()*100
# Out:
# Churn                       No        Yes
# StreamingTV
# No                   66.476868  33.523132
# No internet service  92.595020   7.404980
# Yes                  69.929812  30.070188

# %%
sns.countplot(data=df, x="StreamingTV", hue="Churn", palette="rocket")
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %%
StreamingTV = df[df['StreamingTV']=="No"]

# %%
STV1 = StreamingTV.groupby('StreamingTV')['Churn'].value_counts(normalize=True).unstack()*100

# %%
STV1
# Out:
# Churn               No        Yes
# StreamingTV
# No           66.476868  33.523132

# %%
plt.pie(STV1.loc["No"], labels=STV1.loc["No"].index, autopct="%1.2f%%")
plt.title("No Streaming TV")
# Out:
# Text(0.5, 1.0, 'No Streaming TV')

# %%
StreamingTV = df[df['StreamingTV']=="No internet service"]

# %%
STV2 = StreamingTV.groupby('StreamingTV')['Churn'].value_counts(normalize=True).unstack()*100

# %%
STV2
# Out:
# Churn                      No      Yes
# StreamingTV
# No internet service  92.59502  7.40498

# %%
plt.pie(STV2.loc["No internet service"], labels=STV2.loc["No internet service"].index, autopct="%1.2f%%")
plt.title("No Internet Service")
# Out:
# Text(0.5, 1.0, 'No Internet Service')

# %%
StreamingTv = df[df['StreamingTV']=="Yes"]

# %%
STV3 = StreamingTv.groupby('StreamingTV')['Churn'].value_counts(normalize=True).unstack()*100

# %%
STV3
# Out:
# Churn               No        Yes
# StreamingTV
# Yes          69.929812  30.070188

# %%
plt.pie(STV3.loc["Yes"], labels=STV3.loc["Yes"].index, autopct="%1.2f%%")
plt.title("Streaming TV")
# Out:
# Text(0.5, 1.0, 'Streaming TV')
