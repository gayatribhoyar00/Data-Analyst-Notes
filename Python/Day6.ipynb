# %%
# for loop using factorial

# %%
num = int(input("Enter a number :- "))
factorial = 1
for i in range(1, num+1):
  factorial = factorial * i

print("The factorial of no is", factorial)
# Out:
# Enter a number :- 6
# The factorial of no is 720

# %%
# Numpy - numerical python

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
import numpy as np

# %%
a = [1,2,3,4,5,6]

# %%
b = np.array(a)

# %%
type(a)
# Out:
# list

# %%
type(b)
# Out:
# numpy.ndarray

# %%
print(b)
# Out:
# [1 2 3 4 5 6]

# %%
b
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#2D array

# %%
c = np.array([[1,2,3], [4,5,6]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 3D array

# %%
d = np.array([[[1,2], [3,4]],
             [[4,5], [6,7]]])

# %%
d
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[4, 5],
#         [6, 7]]])

# %%
# attributed

# %%
b.ndim
# Out:
# 1

# %%
c.ndim
# Out:
# 2

# %%
d.ndim
# Out:
# 3

# %%
d.shape
# Out:
# (2, 2, 2)

# %%
c.shape
# Out:
# (2, 3)

# %%
c.size
# Out:
# 6

# %%
c.dtype
# Out:
# dtype('int64')

# %%
# int whole no - int8, int16, int32, int64
# positive int - unsigned int - np.uint16,32
# float - decimal - float 16,32,64
# boolian - True/False - np.bool_
# string - np.str_ ex - "tushar"
# object - np.object_ ex - "Admin@123"

# %%
# method - .methodname()

# %%
np.random.rand()  # 0 to 1
# Out:
# 0.40111842672622666

# %%
np.random.rand(5)
# Out:
# array([0.07131284, 0.60543277, 0.57555676, 0.96460652, 0.92158406])

# %%
np.random.rand(2,3)
# Out:
# array([[0.21566803, 0.44954268, 0.46328479],
#        [0.83980855, 0.14107252, 0.84417557]])

# %%
np.random.randn(5)
# Out:
# array([-0.19150477, -0.98327069,  1.07029148,  0.4680344 ,  0.09218214])

# %%
np.random.randint(1,7)
# Out:
# 6

# %%
np.mean(c)
# Out:
# np.float64(3.5)

# %%
np.max(c)
# Out:
# np.int64(6)

# %%
np.min(c)
# Out:
# np.int64(1)

# %%
np.std(c)
# Out:
# np.float64(1.707825127659933)

# %%
np.var(c)
# Out:
# np.float64(2.9166666666666665)

# %%
c.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
c.reshape(6,1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %% [markdown]
# # Pandas - panel data
# - build on numpy library
# - deals with Series and DataFrame

# %%
import numpy as np
import pandas as pd

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
num = [45,84,56,95]

# %%
pd.Series(num)
# Out:
# 0    45
# 1    84
# 2    56
# 3    95
# dtype: int64

# %%
index_name = ["row1", "row2", "row3", "row4"]

# %%
pd.Series(num, index = index_name, name= "Column1")
# Out:
# row1    45
# row2    84
# row3    56
# row4    95
# Name: Column1, dtype: int64

# %%
data = {"name": ["pradip", "gayatri", "pratiksha"],
        "Age": [18,10,5],
        "City": ["Dubai", "America", "Amazon"]}

# %%
pd.Series(data)
# Out:
# name    [pradip, gayatri, pratiksha]
# Age                      [18, 10, 5]
# City        [Dubai, America, Amazon]
# dtype: object

# %%
df = pd.DataFrame(data, index=['r1', 'r2','r3'])

# %%
df
# Out:
#          name  Age     City
# r1     pradip   18    Dubai
# r2    gayatri   10  America
# r3  pratiksha    5   Amazon

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.dtypes
# Out:
# name    object
# Age      int64
# City    object
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['name', 'Age', 'City'], dtype='object')

# %%
df.index
# Out:
# Index(['r1', 'r2', 'r3'], dtype='object')

# %%
df.values
# Out:
# array([['pradip', 18, 'Dubai'],
#        ['gayatri', 10, 'America'],
#        ['pratiksha', 5, 'Amazon']], dtype=object)
