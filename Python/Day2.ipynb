# %%
# Comparative operator

# %%
# = equal to - assign operator

# %%
a = 10

# %%
city = "wardha"

# %%
print (city)
# Out:
# wardha

# %%
# comparator operator ==

# %%
10 == 10
# Out:
# True

# %%
10 == 5
# Out:
# False

# %%
a = 20
b = 30

# %%
a == b
# Out:
# False

# %%
# not equal to

# %%
10 != 20
# Out:
# True

# %%
20 != 20
# Out:
# False

# %%
# greater than or less than equal to

# %%
8 > 12
# Out:
# False

# %%
12 > 8
# Out:
# True

# %%
12 < 15
# Out:
# True

# %%
8 > 8
# Out:
# False

# %%
8 >= 8
# Out:
# True

# %%
9 <= 9
# Out:
# True

# %%
# logical operators (and / or / not)

# %%
5 == 5 and 4 == 5
# Out:
# False

# %%
5 == 5 and 4 == 4
# Out:
# True

# %%
5 == 5 or 4 == 3
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
not(5==5)
# Out:
# False

# %%
# assign with increment

# %%
a = 10

# %%
a = a + 1

# %%
a
# Out:
# 11

# %%
b = 10

# %%
b += 1

# %%
b
# Out:
# 11

# %%
b -= 2

# %%
b
# Out:
# 9

# %%
# print function (imp)

# %%
a = "welcome to dream with data"

# %%
a
# Out:
# 'welcome to dream with data'

# %%
print(a)
# Out:
# welcome to dream with data

# %%
b = "harsh"

# %%
print("welcome", b)
# Out:
# welcome harsh

# %%
c = 24

# %%
# simple print function

# %%
print ("my name is", b, "and my age is", c)
# Out:
# my name is harsh and my age is 24

# %%
# f string print function

# %%
print (f"my name is {b} and my age is {c}")
# Out:
# my name is harsh and my age is 24

# %%
# Typecasting - (imp)

# %%
x = 5.9

# %%
type(x)
# Out:
# float

# %%
int(x)
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
float(a)
# Out:
# 10.0

# %%
b = 1234

# %%
b
# Out:
# 1234

# %%
str(b)
# Out:
# '1234'

# %%
a = [1,2,3]

# %%
tuple(a)
# Out:
# (1, 2, 3)

# %%
set(a)
# Out:
# {1, 2, 3}

# %%
x = {7,8,9}

# %%
list(x)
# Out:
# [8, 9, 7]

# %%
# sequencial data type (imp)

# %% [markdown]
# # LIST
#
# - Store multiple values in one variable
# - Access, modify or remove elements easily
# - Mutable(possible to change elements)
# - Hetrogeneous - can store different data type
# - Ordered - index wise
# - Easy Iteration (one by one element can access)

# %%
# empty list

# %%
a = [ ] # empty list

# %%
#hetrogeneous

# %%
b = [5,8.9, True, False, "Banana", None]

# %%
type(b)
# Out:
# list

# %%
fruits = ["bamana", "cherry", "apple", "mango"]

# %%
# nested list

# %%
nested = [[1,2], [4,5,6], [[54,45]]]

# %%
# indexing - 0,1,2,3,4,5,6
# -1,-2,-3,-4,-5

# %%
fruits = ["apple", "banana", "cherry", "orange", "mango"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-3]
# Out:
# 'cherry'

# %%
# slicing - access one less elements

# %%
fruits[0:3]
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[2:5]
# Out:
# ['cherry', 'orange', 'mango']

# %%
fruits[::]
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'mango']

# %%
# methods - (variable.method())
#.method(callable)
#.method() - non callable

# %%
# . append() - # add only one element at end

# %%
fruits.append("banana")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'mango', 'banana']

# %%
# .extend() - add more than one element another list

# %%
fruits.extend([4,5,6])

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'mango', 'banana', 4, 5, 6]

# %%
# .insert - insert in particular location

# %%
fruits.insert(1, "pineapple")

# %%
fruits
# Out:
# ['pineapple',
#  'pineapple',
#  'pineapple',
#  'banana',
#  'cherry',
#  'orange',
#  'mango',
#  'banana',
#  4,
#  5,
#  6]

# %%
# .remove

# %%
fruits.remove("apple")

# %%
fruits
# Out:
# ['pineapple', 'banana', 'cherry', 'orange', 'mango', 'banana', 4, 5, 6]

# %%
# .pop() - remove with index position

# %%
fruits.pop(0)
# Out:
# 'pineapple'

# %%
fruits
# Out:
# ['pineapple', 'banana', 'cherry', 'orange', 'mango', 'banana', 4, 5, 6]

# %%
fruits.pop()
# Out:
# 6

# %%
# .clear()

# %%
fruits.clear()

# %%
fruits
# Out:
# []

# %%
# .index - need location

# %%
lst = [10,20,30,40,40,50,50,50,50,50,60,60,70,80]

# %%
lst.index(50)
# Out:
# 5

# %%
# .count()

# %%
lst.count(60)
# Out:
# 2

# %%
lst.sort()

# %%
lst
# Out:
# [10, 20, 30, 40, 40, 50, 50, 50, 50, 50, 60, 60, 70, 80]

# %%
# .reverse()

# %%
lst.reverse()

# %%
lst
# Out:
# [80, 70, 60, 60, 50, 50, 50, 50, 50, 40, 40, 30, 20, 10]

# %%
# function -

# %%
len(lst)
# Out:
# 14

# %%
max(lst)
# Out:
# 80

# %%
min(lst)
# Out:
# 10

# %%
sum(lst)
# Out:
# 660
