# %%
# FUNCTION - REUSABLE BLOCK OF CODE
# SYNTAX - function_name (callable entity)

# %%
# in build & user definable

# %%
# in built

# %%
print("Hello, welcome to dream with data")
# Out:
# Hello, welcome to dream with data

# %%
len("Hello")
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
int(45.6)
# Out:
# 45

# %%
float(4)
# Out:
# 4.0

# %%
min([4,5,6,7,8,9,10])
# Out:
# 4

# %%
max([1,2,3,4,5,6,7,8,9])
# Out:
# 9

# %%
# user defined function
# syntak -
# def function name(callable value) (def-define)
# what it return

# %%
def greet(name):
  print("Good Morning", name)

# %%
greet("Gayatri")
# Out:
# Good Morning Gayatri

# %%
greet("Tushar")
# Out:
# Good Morning Tushar

# %%
def sq(num):
  return num * num

# %%
sq(18)
# Out:
# 324

# %%
sq(5)
# Out:
# 25

# %%
# default value set

# %%
def greeting(name="Guest"):
  print("Hello", name)

# %%
greeting("Gayatri")
# Out:
# Hello Gayatri

# %%
greeting()
# Out:
# Hello Guest

# %%
# external functions

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
# anonymous function - function without name (imp)

# %%
# LAMBDA / MAP / FILTER

# %%
# LAMBDA ARGUMENTS/ VARIABLE : EXPRESSION / OPERATION

# %%
sq = lambda x : x * x

# %%
sq(9)
# Out:
# 81

# %%
add = lambda a , b : a + b

# %%
add(7,9)
# Out:
# 16

# %%
# map - it applies a function to each item in list

# %%
num = [1,2,3,4,5,6,7,8,9]

# %%
sqr = list(map(lambda x : x * x, num ))

# %%
sqr
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# filter - as per condition

# %%
num
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
sqrr = list(filter(lambda x : x % 2 == 0, num))

# %%
sqrr
# Out:
# [2, 4, 6, 8]

# %%
even = list(map(lambda x : x * x, filter(lambda x : x % 2 == 0 , num)))

# %%
even
# Out:
# [4, 16, 36, 64]

# %%
# Numpy - Numerical Python

# %%
# use for any operation  related to array
# algebric , statistics and many more
# it is a library

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
import numpy as np

# %%
# as - alias
